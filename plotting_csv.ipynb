# %%
# import the pandas data analysis library and refer to it as pd
import pandas as pd


# read the csv file
df = pd.read_csv("influx_asdf.csv")
df = pd.DataFrame(df)


# view the first few rows of data
df.head(500)
# Out:
# Uruchomienie komórek z elementem „c:\Users\anxs\AppData\Local\Programs\Python\Python311\python.exe” wymaga pakietu ipykernel.
#
# Uruchom następujące polecenie, aby zainstalować element „ipykernel” w środowisku języka Python.
#
# Polecenie: „c:/Users/anxs/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall”

# %%
# display the data type of each column in our DataFrame
df.dtypes
# Out:
# _timestamp               object
# _Wind_Data_aws          float64
# _Wind_Data_awd          float64
# _V1P_load_value         float64
# _V1S_load_value         float64
# _Headstay_load_value    float64
# dtype: object

# %%
import matplotlib.pyplot as plt

x = [df._timestamp]
y = [df._Wind_Data_aws, df._Wind_Data_awd, df._V1P_load_value, df._V1S_load_value, df._Headstay_load_value]
plt.scatter(df._timestamp, df._Wind_Data_awd)
plt.scatter(df._timestamp, df._Wind_Data_aws)
plt.scatter(df._timestamp, df._V1P_load_value)
plt.scatter(df._timestamp, df._V1S_load_value)
plt.scatter(df._timestamp, df._Headstay_load_value)


plt.show()
